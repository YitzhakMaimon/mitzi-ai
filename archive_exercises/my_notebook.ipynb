# %% [markdown]
# import numpy as np
# import matplotlib.pyplot as plt
# N = 50
# x = np.random.rand(N)
# y = np.random.rand(N)
# colors = np.random.rand(N)
# area = np.pi * ( 15 * np.random.rand(N)) ** 2
# plt.scatter(x, y, s=area, c=colors, alpha=0.5)
# plt.show()

# %%
import sys
# !{sys.executable} -m pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * ( 15 * np.random.rand(N)) ** 2
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# # Title

# %% [markdown]
# # Title

# %% [markdown]
# #Title
# ##Title

# %% [markdown]
# # Title
# ## Title
# ### Title

# %% [markdown]
# <span style = "color:red">red</span>

# %% [markdown]
# __bold__

# %% [markdown]
# *bold*

# %% [markdown]
# **bold**

# %% [markdown]
# *na*

# %%
x = "*****#### Hello World &&&$$$$"
y = x.replace("*", "").replace("#", "").replace("&", "").replace("$", "")
z = y.lower()
_all = z + y
print(x)
print(y)
print(_all)
# Out:
# *****#### Hello World &&&$$$$
#  Hello World
#  hello world  Hello World

# %%
x = "*****#### Hello World &&&$$$$"
y = x.strip("*#&$ ")
z = y.lower()
_all = z + y
print(x,y,_all)
# Out:
# *****#### Hello World &&&$$$$ Hello World hello world

# %%
word = "alex kuznetsov"
new_list = word.split()
new_list.append("tt")
for item in new_list:
    print(item[1:4])
# Out:
# lex
# uzn
# t

# %% [markdown]
# לעשות את התרגיל שוב כי ב11 כבר לא הצלחתי להתרכז מעורפל

# %%
dict_1 = {1:200, "a" : "df", 2:34}
dict_2 = {2:34, 5:60, 1:200}
set1 = set(dict_1.values())
set2 = set(dict_2.values())
set_union = set1 | set2
set_unique = set1 ^ set2
print(dict_1)
print(dict_2)
print(set_union)
print(set_unique)
# Out:
# {1: 200, 'a': 'df', 2: 34}
# {2: 34, 5: 60, 1: 200}
# {34, 200, 'df', 60}
# {'df', 60}

# %% [markdown]
# מצגת 2

# %% [markdown]
# `Reminder`

# %%
word = "AI engineer"
list = word.split()
word1_length = len(list[0])
word2_length = len(list[1])
print(word1_length == word2_length)
print(word1_length <= word2_length)
# Out:
# False
# True

# %% [markdown]
# פונקציה היא אובייקט ויש לה ID
# לחזור על "טפל"
# לוקלי וגלובלי

# %%
def add(*value)

# %% [markdown]
# גם נקודתים וגם -< זה רק רמז>

# %%
def zugi(x,y):
    
    return x % y == 0

print(zugi(10,3))
# Out:
# False

# %%
def zugi(*values):
    if len(values) >= 2 & values[1] != 0:
    
        return values[0] % values[1] == 0

print(zugi(10,0,3))
# Out:
# None

# %%
def zugi(*values): #דוגמא TRY CATCH
    try:
        return x/y
    except ZeroDivisionError:
        return "ZeroDivision"
    
        return values[0] % values[1] == 0

print(zugi(10,0,3))

# %%
import ex.py
class Computer:
    def config(self):
        print("hi")

c1 = Computer()
print(type(c1))
print(__name__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 import ex.py
#       2 class Computer:
#       3     def config(self):
#       4         print("hi")
#
# ModuleNotFoundError: No module named 'ex.py'; 'ex' is not a package

# %% [markdown]
# להבין __MAIN__
# לעשות אימפורט ביןו שני קבצים
